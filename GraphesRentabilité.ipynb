# %%
import matplotlib.pyplot as plt
import numpy as np

# Create the vectors X and Y
x = np.array(range(80))
xb = np.array(range(160))
y = 500 +(x/10)*1.1+1.1*(x/10)
yb = 800 + (1.3*(xb/20)) + 1.3*(xb / 20)
# Create the plot
plt.plot(x,y, label='Déneigeuse de type 1')
plt.plot(xb,yb, label='Déneigeuse de type 2')
plt.xlabel('Distance parcourue (en km)')

plt.ylabel('Coût total')
plt.legend()

# Add a title
plt.title('Comparaison des coûts des déneigeuses sur les 8 premières heures')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xa = np.array(range(80))
xba = np.array(range(160))
ya = 500 +(xa/10)*1.1+1.1*(xa/10)
yba = 800 + (1.3*(xba/20)) + 1.3*(xba / 20)
# Create the plot
plt.plot(xa,ya, label='Déneigeuse de type 1')
plt.plot(xba,yba, label='Déneigeuse de type 2')
# la distance limite sur une journée est de 240 km pour le type 1 et 480km pour le type 2
x = np.array(range(80,240))
xb = np.array(range(160,480))
#y = 500 +1.1 * 80+ (1.1 * (x/10)) + 1.3*((x - 8)/ 10)
y = (1.1 * ((x-80)/10)) + 1.3*(((x-80))/ 10)+ya[79]
yb = (1.3 * ((xb-160)/20)) + (1.5 * (((xb-160)) / 20))+yba[159]
#yb = 800 + (1.3 * (xb/20)) + (1.3 * 160) + (1.5 * ((xb -8) / 20))

plt.plot(x,y, label='Déneigeuse de type 1')
plt.plot(xb,yb, label='Déneigeuse de type 2')
plt.xlabel('Distance parcourue (en km)')

plt.ylabel('Coût total')
plt.legend()

plt.title('Comparaison des coûts des déneigeuses sur une journée')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


xa = np.array(range(80))
xba = np.array(range(160))
ya = 500 +(xa/10)*1.1+1.1*(xa/10)
yba = 800 + (1.3*(xba/20)) + 1.3*(xba / 20)
# Create the plot
plt.plot(xa,ya, label='Déneigeuse de type 1')
plt.plot(xba,yba, label='Déneigeuse de type 2')
# la distance limite sur une journée est de 240 km pour le type 1 et 480km pour le type 2
x = np.array(range(80,3500))
xb = np.array(range(160,3500))
#y = 500 +1.1 * 80+ (1.1 * (x/10)) + 1.3*((x - 8)/ 10)
y = (1.1 * ((x-80)/10)) + 1.3*(((x-80))/ 10)+ya[79]
yb = (1.3 * ((xb-160)/20)) + (1.5 * (((xb-160)) / 20))+yba[159]
#yb = 800 + (1.3 * (xb/20)) + (1.3 * 160) + (1.5 * ((xb -8) / 20))

plt.plot(x,y, label='Déneigeuse de type 1')
plt.plot(xb,yb, label='Déneigeuse de type 2')
plt.xlabel('Distance parcourue (en km)')

plt.ylabel('Coût total')
plt.legend()

plt.title('Allongement des courbes prouvant une intersection')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xa = np.array(range(80))
xba = np.array(range(160))
ya = 500 +(xa/10)*1.1+1.1*(xa/10)
yba = 800 + (1.3*(xba/20)) + 1.3*(xba / 20)
plt.plot(xa,ya, label='Déneigeuse de type 1')
plt.plot(xba,yba, label='Déneigeuse de type 2')
x = np.array(range(80,240))
xb = np.array(range(160,480))
y = (1.1 * ((x-80)/10)) + 1.3*(((x-80))/ 10)+ya[79]
yb = (1.3 * ((xb-160)/20)) + (1.5 * (((xb-160)) / 20))+yba[159]
xfin8 = np.array(range(240, 320))
yfin8 = 500 +(xfin8/10)*1.1+1.1*(xfin8/10)+ya[79]
xfin =  np.array(range(320, 480))
yfinal = (1.1 * ((xfin-320)/10)) + 1.3*(((xfin-320))/ 10)+yfin8[79]
plt.plot(xfin8,yfin8, label='Déneigeuse de type 1 ')
plt.plot(x,y, label='Déneigeuse de type 1 ')
plt.plot(xb,yb, label='Déneigeuse de type 2')
plt.plot(xfin,yfinal, label='Déneigeuse de type 2')
plt.xlabel('Distance parcourue (en km)')

plt.ylabel('Coût total')
plt.legend()

plt.title('Comparaison des coûts des déneigeuses en fonction de la distance')
plt.show()
